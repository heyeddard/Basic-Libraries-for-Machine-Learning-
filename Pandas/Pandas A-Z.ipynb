# %% [markdown]
# # create pandas series

# %%
import pandas as pd

# %%
a = pd.Series([1,2,3,4,5])

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a[3]
# Out:
# 4

# %%
a = pd.Series(['a','b','c'])

# %%
a
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
a = pd.date_range(start='30-04-2020',end='15-06-2020')

# %%
a
# Out:
# DatetimeIndex(['2020-04-30', '2020-05-01', '2020-05-02', '2020-05-03',
#                '2020-05-04', '2020-05-05', '2020-05-06', '2020-05-07',
#                '2020-05-08', '2020-05-09', '2020-05-10', '2020-05-11',
#                '2020-05-12', '2020-05-13', '2020-05-14', '2020-05-15',
#                '2020-05-16', '2020-05-17', '2020-05-18', '2020-05-19',
#                '2020-05-20', '2020-05-21', '2020-05-22', '2020-05-23',
#                '2020-05-24', '2020-05-25', '2020-05-26', '2020-05-27',
#                '2020-05-28', '2020-05-29', '2020-05-30', '2020-05-31',
#                '2020-06-01', '2020-06-02', '2020-06-03', '2020-06-04',
#                '2020-06-05', '2020-06-06', '2020-06-07', '2020-06-08',
#                '2020-06-09', '2020-06-10', '2020-06-11', '2020-06-12',
#                '2020-06-13', '2020-06-14', '2020-06-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
type(a)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# # pandas DataFrame

# %%
import numpy as np

# %%
a = np.random.randint(low = 10, high = 100, size = [20,])
b = np.random.choice(['sugam','sachin','vasu','srushti','kshtiz'],20)
c = np.random.choice([1,2,3,45,6],20)

# %%
d = list(zip(a,b,c))

# %%
df = pd.DataFrame(data=d,columns=['a','b','c'])

# %%
df
# Out:
#      a        b   c
# 0   10   kshtiz   2
# 1   83   sachin  45
# 2   21     vasu   6
# 3   20  srushti   3
# 4   47   sachin  45
# 5   41  srushti   3
# 6   66   kshtiz   3
# 7   24   sachin   6
# 8   13   kshtiz   1
# 9   51   kshtiz   1
# 10  52   kshtiz   2
# 11  59  srushti   3
# 12  91   kshtiz   2
# 13  15  srushti   1
# 14  52   sachin  45
# 15  78   sachin   6
# 16  49     vasu  45
# 17  27   sachin   1
# 18  16     vasu   3
# 19  20     vasu  45

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
a = np.random.randint(low = 10, high = 100, size = [20,])
b = np.random.choice(['sugam','sachin','vasu','srushti','kshtiz'],20)
c = np.random.choice([1,2,3,45,6],20)

# %%
df = pd.DataFrame({'a':a,'b':b,'c':c})

# %%
df
# Out:
#      a        b   c
# 0   58     vasu   3
# 1   40   kshtiz   3
# 2   93     vasu   6
# 3   57    sugam   1
# 4   54    sugam   3
# 5   40     vasu  45
# 6   89   kshtiz  45
# 7   56    sugam   6
# 8   68   kshtiz   2
# 9   78     vasu   3
# 10  29     vasu  45
# 11  32  srushti  45
# 12  93    sugam   6
# 13  19    sugam  45
# 14  50   sachin   1
# 15  19   kshtiz   1
# 16  49   sachin  45
# 17  99    sugam  45
# 18  20  srushti   1
# 19  53    sugam   1

# %%
df.head()
# Out:
#     a       b  c
# 0  58    vasu  3
# 1  40  kshtiz  3
# 2  93    vasu  6
# 3  57   sugam  1
# 4  54   sugam  3

# %%
df.tail()
# Out:
#      a        b   c
# 15  19   kshtiz   1
# 16  49   sachin  45
# 17  99    sugam  45
# 18  20  srushti   1
# 19  53    sugam   1

# %%
df.shape
# Out:
# (20, 3)

# %%
df.columns
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
df.a
# Out:
# 0     58
# 1     40
# 2     93
# 3     57
# 4     54
# 5     40
# 6     89
# 7     56
# 8     68
# 9     78
# 10    29
# 11    32
# 12    93
# 13    19
# 14    50
# 15    19
# 16    49
# 17    99
# 18    20
# 19    53
# Name: a, dtype: int64

# %%
df['a']
# Out:
# 0     58
# 1     40
# 2     93
# 3     57
# 4     54
# 5     40
# 6     89
# 7     56
# 8     68
# 9     78
# 10    29
# 11    32
# 12    93
# 13    19
# 14    50
# 15    19
# 16    49
# 17    99
# 18    20
# 19    53
# Name: a, dtype: int64

# %%
df['b']
# Out:
# 0        vasu
# 1      kshtiz
# 2        vasu
# 3       sugam
# 4       sugam
# 5        vasu
# 6      kshtiz
# 7       sugam
# 8      kshtiz
# 9        vasu
# 10       vasu
# 11    srushti
# 12      sugam
# 13      sugam
# 14     sachin
# 15     kshtiz
# 16     sachin
# 17      sugam
# 18    srushti
# 19      sugam
# Name: b, dtype: object

# %%
df['c']
# Out:
# 0      3
# 1      3
# 2      6
# 3      1
# 4      3
# 5     45
# 6     45
# 7      6
# 8      2
# 9      3
# 10    45
# 11    45
# 12     6
# 13    45
# 14     1
# 15     1
# 16    45
# 17    45
# 18     1
# 19     1
# Name: c, dtype: int64

# %%
df['c'].describe()
# Out:
# count    20.000000
# mean     17.600000
# std      20.689178
# min       1.000000
# 25%       1.750000
# 50%       4.500000
# 75%      45.000000
# max      45.000000
# Name: c, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
# a    20 non-null int64
# b    20 non-null object
# c    20 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 608.0+ bytes

# %%
df.values
# Out:
# array([[58, 'vasu', 3],
#        [40, 'kshtiz', 3],
#        [93, 'vasu', 6],
#        [57, 'sugam', 1],
#        [54, 'sugam', 3],
#        [40, 'vasu', 45],
#        [89, 'kshtiz', 45],
#        [56, 'sugam', 6],
#        [68, 'kshtiz', 2],
#        [78, 'vasu', 3],
#        [29, 'vasu', 45],
#        [32, 'srushti', 45],
#        [93, 'sugam', 6],
#        [19, 'sugam', 45],
#        [50, 'sachin', 1],
#        [19, 'kshtiz', 1],
#        [49, 'sachin', 45],
#        [99, 'sugam', 45],
#        [20, 'srushti', 1],
#        [53, 'sugam', 1]], dtype=object)

# %%
df.set_index('c',inplace = True)

# %%
df
# Out:
#      a        b
# c
# 3   58     vasu
# 3   40   kshtiz
# 6   93     vasu
# 1   57    sugam
# 3   54    sugam
# 45  40     vasu
# 45  89   kshtiz
# 6   56    sugam
# 2   68   kshtiz
# 3   78     vasu
# 45  29     vasu
# 45  32  srushti
# 6   93    sugam
# 45  19    sugam
# 1   50   sachin
# 1   19   kshtiz
# 45  49   sachin
# 45  99    sugam
# 1   20  srushti
# 1   53    sugam

# %%
df.sort_index(axis=0,ascending = False)
# Out:
#      a        b
# c
# 45  29     vasu
# 45  32  srushti
# 45  99    sugam
# 45  49   sachin
# 45  40     vasu
# 45  89   kshtiz
# 45  19    sugam
# 6   93     vasu
# 6   56    sugam
# 6   93    sugam
# 3   58     vasu
# 3   40   kshtiz
# 3   78     vasu
# 3   54    sugam
# 2   68   kshtiz
# 1   50   sachin
# 1   19   kshtiz
# 1   57    sugam
# 1   20  srushti
# 1   53    sugam

# %%
df.sort_values(by = 'a',ascending=False)
# Out:
#      a        b
# c
# 45  99    sugam
# 6   93    sugam
# 6   93     vasu
# 45  89   kshtiz
# 3   78     vasu
# 2   68   kshtiz
# 3   58     vasu
# 1   57    sugam
# 6   56    sugam
# 3   54    sugam
# 1   53    sugam
# 1   50   sachin
# 45  49   sachin
# 3   40   kshtiz
# 45  40     vasu
# 45  32  srushti
# 45  29     vasu
# 1   20  srushti
# 45  19    sugam
# 1   19   kshtiz

# %%
df.drop('a',axis=1)
# Out:
#           b
# c
# 3      vasu
# 3    kshtiz
# 6      vasu
# 1     sugam
# 3     sugam
# 45     vasu
# 45   kshtiz
# 6     sugam
# 2    kshtiz
# 3      vasu
# 45     vasu
# 45  srushti
# 6     sugam
# 45    sugam
# 1    sachin
# 1    kshtiz
# 45   sachin
# 45    sugam
# 1   srushti
# 1     sugam

# %%
df.head()
# Out:
#     a       b
# c
# 3  58    vasu
# 3  40  kshtiz
# 6  93    vasu
# 1  57   sugam
# 3  54   sugam

# %%
df.iloc[[0,1]]
# Out:
#     a       b
# c
# 3  58    vasu
# 3  40  kshtiz

# %%
df.iloc[1:3,1]
# Out:
# c
# 3    kshtiz
# 6      vasu
# Name: b, dtype: object

# %%
df.head()
# Out:
#     a       b
# c
# 3  58    vasu
# 3  40  kshtiz
# 6  93    vasu
# 1  57   sugam
# 3  54   sugam

# %%
df
# Out:
#      a        b
# c
# 3   58     vasu
# 3   40   kshtiz
# 6   93     vasu
# 1   57    sugam
# 3   54    sugam
# 45  40     vasu
# 45  89   kshtiz
# 6   56    sugam
# 2   68   kshtiz
# 3   78     vasu
# 45  29     vasu
# 45  32  srushti
# 6   93    sugam
# 45  19    sugam
# 1   50   sachin
# 1   19   kshtiz
# 45  49   sachin
# 45  99    sugam
# 1   20  srushti
# 1   53    sugam

# %%
df.iloc[0,:]
# Out:
# a      58
# b    vasu
# Name: 3, dtype: object

# %%
df.loc[2]
# Out:
# a        68
# b    kshtiz
# Name: 2, dtype: object

# %%
df.loc[[2,1,6]]
# Out:
#     a        b
# c
# 2  68   kshtiz
# 1  57    sugam
# 1  50   sachin
# 1  19   kshtiz
# 1  20  srushti
# 1  53    sugam
# 6  93     vasu
# 6  56    sugam
# 6  93    sugam

# %%
df.loc[[2,4],'a':'b']
# Out:
# /Users/sugamagarwal/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#       a       b
# c
# 2  68.0  kshtiz
# 4   NaN     NaN

# %%
df.loc[a>56]
# Out:
#      a       b
# c
# 3   58    vasu
# 6   93    vasu
# 1   57   sugam
# 45  89  kshtiz
# 2   68  kshtiz
# 3   78    vasu
# 6   93   sugam
# 45  99   sugam

# %%
df.loc[(df.a>56) | (df. a == 1),:]
# Out:
#      a       b
# c
# 3   58    vasu
# 6   93    vasu
# 1   57   sugam
# 45  89  kshtiz
# 2   68  kshtiz
# 3   78    vasu
# 6   93   sugam
# 45  99   sugam

# %%
d1 = pd.read_csv("weather.csv")

# %%
d1
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df_group = d1.groupby("outlook")

# %%
for temperature in df_group:
    print(temperature)
# Out:
# ('overcast',     outlook temperature humidity  windy play
# 0  overcast         hot     high  False  yes
# 1  overcast        cool   normal   True  yes
# 2  overcast        mild     high   True  yes
# 3  overcast         hot   normal  False  yes)
# ('rainy',   outlook temperature humidity  windy play
# 4   rainy        mild     high  False  yes
# 5   rainy        cool   normal  False  yes
# 6   rainy        cool   normal   True   no
# 7   rainy        mild   normal  False  yes
# 8   rainy        mild     high   True   no)
# ('sunny',    outlook temperature humidity  windy play
# 9    sunny         hot     high  False   no
# 10   sunny         hot     high   True   no
# 11   sunny        mild     high  False   no
# 12   sunny        cool   normal  False  yes
# 13   sunny        mild   normal   True  yes)

# %%
df_group.get_group("rainy")
# Out:
#   outlook temperature humidity  windy play
# 4   rainy        mild     high  False  yes
# 5   rainy        cool   normal  False  yes
# 6   rainy        cool   normal   True   no
# 7   rainy        mild   normal  False  yes
# 8   rainy        mild     high   True   no

# %%
df_group.describe()
# Out:
#          temperature                   humidity                     windy  \
#                count unique   top freq    count unique     top freq count
# outlook
# overcast           4      3   hot    2        4      2  normal    2     4
# rainy              5      2  mild    3        5      2  normal    3     5
# sunny              5      3   hot    2        5      2    high    3     5
#
#                              play
#          unique    top freq count unique  top freq
# outlook
# overcast      2   True    2     4      1  yes    4
# rainy         2  False    3     5      2  yes    3
# sunny         2  False    3     5      2   no    3

# %%
def hot_temp(x):
    if(x=='hot'):
        return True

# %%
d1['hot_temp']=d1['temperature'].apply(hot_temp)

# %%
d1
# Out:
#      outlook temperature humidity  windy play hot_temp
# 0   overcast         hot     high  False  yes     True
# 1   overcast        cool   normal   True  yes     None
# 2   overcast        mild     high   True  yes     None
# 3   overcast         hot   normal  False  yes     True
# 4      rainy        mild     high  False  yes     None
# 5      rainy        cool   normal  False  yes     None
# 6      rainy        cool   normal   True   no     None
# 7      rainy        mild   normal  False  yes     None
# 8      rainy        mild     high   True   no     None
# 9      sunny         hot     high  False   no     True
# 10     sunny         hot     high   True   no     True
# 11     sunny        mild     high  False   no     None
# 12     sunny        cool   normal  False  yes     None
# 13     sunny        mild   normal   True  yes     None

# %%
d1['high_humid'] = d1['humidity'].apply(lambda x: True if (x=='high') else False)

# %%
d1
# Out:
#      outlook temperature humidity  windy play hot_temp  high_humid
# 0   overcast         hot     high  False  yes     True        True
# 1   overcast        cool   normal   True  yes     None       False
# 2   overcast        mild     high   True  yes     None        True
# 3   overcast         hot   normal  False  yes     True       False
# 4      rainy        mild     high  False  yes     None        True
# 5      rainy        cool   normal  False  yes     None       False
# 6      rainy        cool   normal   True   no     None       False
# 7      rainy        mild   normal  False  yes     None       False
# 8      rainy        mild     high   True   no     None        True
# 9      sunny         hot     high  False   no     True        True
# 10     sunny         hot     high   True   no     True        True
# 11     sunny        mild     high  False   no     None        True
# 12     sunny        cool   normal  False  yes     None       False
# ...

# %%
# can also read from excel file , submit data frame to excel file and same for csv file also.

# %%
#merging and concat 
d1 = pd.DataFrame([['a',1],['b',2]],columns=['col1','number'])

# %%
d2 = pd.DataFrame([['c',3,'lion'],['d',4,'tiger']],columns=['letter','number','animal'])

# %%
d1
# Out:
#   col1  number
# 0    a       1
# 1    b       2

# %%
d2
# Out:
#   letter  number animal
# 0      c       3   lion
# 1      d       4  tiger

# %%
pd.concat([d1,d2],axis=0)
# Out:
# /Users/sugamagarwal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#   animal col1 letter  number
# 0    NaN    a    NaN       1
# 1    NaN    b    NaN       2
# 0   lion  NaN      c       3
# 1  tiger  NaN      d       4

# %%
pd.concat([d1,d2],axis=0,ignore_index=True)
# Out:
# /Users/sugamagarwal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#   animal col1 letter  number
# 0    NaN    a    NaN       1
# 1    NaN    b    NaN       2
# 2   lion  NaN      c       3
# 3  tiger  NaN      d       4

# %%
pd.concat([d1,d2],axis=1)
# Out:
#   col1  number letter  number animal
# 0    a       1      c       3   lion
# 1    b       2      d       4  tiger

# %%
d1
# Out:
#   col1  number
# 0    a       1
# 1    b       2

# %%
d1 = pd.DataFrame({"city":["lucknow","agra","delhi","agra"],
                  "temp":[32,22,43,26]})

# %%
d1
# Out:
#       city  temp
# 0  lucknow    32
# 1     agra    22
# 2    delhi    43
# 3     agra    26

# %%
d2 = pd.DataFrame({"city":["agra","delhi","bombay"],
                  "humidity":[78,65,90]})

# %%
df = pd.merge(d1,d2,on='city')

# %%
df
# Out:
#     city  temp  humidity
# 0   agra    22        78
# 1   agra    26        78
# 2  delhi    43        65

# %%
#you can also do merge with the help of outer , inner join

# %%
#pivot

# %%
help(pd.DataFrame.pivot_table)
# Out:
# Help on function pivot_table in module pandas.core.frame:
#
# pivot_table(self, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False)
#     Create a spreadsheet-style pivot table as a DataFrame. The levels in
#     the pivot table will be stored in MultiIndex objects (hierarchical
#     indexes) on the index and columns of the result DataFrame.
#
#     Parameters
#     ----------
#     values : column to aggregate, optional
#     index : column, Grouper, array, or list of the previous
#         If an array is passed, it must be the same length as the data. The
#         list can contain any of the other types (except list).
#         Keys to group by on the pivot table index.  If an array is passed,
#         it is being used as the same manner as column values.
#     columns : column, Grouper, array, or list of the previous
#         If an array is passed, it must be the same length as the data. The
# ...
